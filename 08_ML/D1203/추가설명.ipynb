# %% [markdown]
# - GPU : 라이브러리 프레임워크가 지원함
# - NPU
# - TPU
#      - 이 두개는 성능은 좋지만 라이브러리 지원을 안해서 쓰기 어려움

# %% [markdown]
# - CPU - 사람의 뇌, 연산, 1번에 1개 처리
# - Program - 한글, VSCODE : HDD
# - Process - 클릭 실행 => 메모리
# - Processor - CPU, MCU, GPU => 병렬처리, GRAM

# %% [markdown]
# - DataFrame에서 일부 데이터 추출 slicing
# - -> 메모리 낭비 막기 위해서 View 객체
