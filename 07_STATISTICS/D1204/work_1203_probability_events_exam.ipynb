# %% [markdown]
# ##### 확률 연습문제
#
# 다음은 **사건, 여사건, 독립사건, 조건부확률** 등을 다루는 확률 연습문제입니다.
#
# - 각 문항에 대해 풀이 과정을 서술형으로 적거나, 아래 코드 셀에 파이썬 코드로 계산해 보세요.
# - 필요 시 소수 셋째 자리에서 반올림하여 소수 둘째 자리까지 표현하세요.

# %% [markdown]
# ##### 1. 사건과 여사건
# 어떤 학생이 시험에서 **합격할 확률**이 0.7이다.
#
# 이 학생이 **불합격할 확률(여사건)**을 구하시오.

# %%
# Q1 답안을 여기 작성하세요.
# 서술형 풀이 또는 파이썬 코드를 자유롭게 사용해도 됩니다.

# %% [markdown]
# ##### 2. 사건의 합집합 (Union)
# 한 마을에서
# - 자전거를 가지고 있을 확률: 0.4
# - 킥보드를 가지고 있을 확률: 0.3
# - 둘 다 가지고 있을 확률: 0.15
#
# 이 마을에서 임의의 한 사람을 선택했을 때,
# **자전거나 킥보드 중 적어도 하나**는 가지고 있을 확률을 구하시오.

# %%
# Q2 답안을 여기 작성하세요.
# 서술형 풀이 또는 파이썬 코드를 자유롭게 사용해도 됩니다.

# %% [markdown]
# ##### 3. 사건의 교집합과 독립성
# 어떤 학생이 영어시험과 수학시험에 동시에 합격할 확률이 0.25이다.
# 영어시험에 합격할 확률은 0.5, 수학시험에 합격할 확률은 0.4일 때,
# 두 사건(영어 합격, 수학 합격)은 **독립적인지 여부**를 판단하시오.

# %%
# Q3 답안을 여기 작성하세요.
# 서술형 풀이 또는 파이썬 코드를 자유롭게 사용해도 됩니다.

# %% [markdown]
# ##### 4. 여사건 활용 (주사위)
# 주사위 1개를 한 번 던질 때, **3보다 큰 수(4, 5, 6)** 나올 확률을 구하시오.

# %%
# Q4 답안을 여기 작성하세요.
# 서술형 풀이 또는 파이썬 코드를 자유롭게 사용해도 됩니다.

# %% [markdown]
# ##### 5. 독립사건의 개념
# 동전을 두 번 던진다.
# - 첫 번째에 앞면이 나올 확률: 1/2
# - 두 번째에 앞면이 나올 확률: 1/2
#
# 첫 번째 던지기의 결과가 두 번째 던지기의 결과에 영향을 주지 않는다고 할 때,
# 두 사건(첫 번째 앞면, 두 번째 앞면)은 **독립사건**인지 설명하시오.

# %%
# Q5 답안을 여기 작성하세요.
# 서술형 풀이 또는 파이썬 코드를 자유롭게 사용해도 됩니다.

# %% [markdown]
# ##### 6. 여사건을 이용한 확률 계산 (적어도 1번 성공)
# 동전을 3번 던질 때, **적어도 1번 앞면**이 나올 확률을 구하시오.
# 가능하면 **여사건(한 번도 앞면이 나오지 않을 사건)**을 이용하여 계산해 보시오.

# %%
# Q6 답안을 여기 작성하세요.
# 서술형 풀이 또는 파이썬 코드를 자유롭게 사용해도 됩니다.

# %% [markdown]
# ##### 7. 조건부 확률
# 전체 학생 중 40%는 **프로그래밍을 좋아하고**, 그중 60%는 **파이썬을 좋아한다**고 한다.
#
# 전체 학생 중에서 임의로 한 명을 뽑았을 때, 그 학생이 **파이썬을 좋아할 확률**을 구하시오.

# %%
# Q7 답안을 여기 작성하세요.
# 서술형 풀이 또는 파이썬 코드를 자유롭게 사용해도 됩니다.

# %%
# Q8 답안을 여기 작성하세요.
# 서술형 풀이 또는 파이썬 코드를 자유롭게 사용해도 됩니다.

# %% [markdown]
# ##### 8. 경우의 수를 이용한 확률 (주사위 2개)
# 주사위 2개를 동시에 던질 때, 나온 눈의 **합이 7이 될 확률**을 구하시오.
# 경우의 수를 나열하거나 조합을 이용하여 계산해 보시오.

# %%
# Q8 답안을 여기 작성하세요.
# 서술형 풀이 또는 파이썬 코드를 자유롭게 사용해도 됩니다.

# %% [markdown]
# ##### 9. 사건의 독립성 판단
# 두 사건 A, B에 대해 다음과 같은 정보가 주어진다.
# - P(A) = 0.6
# - P(B) = 0.5
# - P(A ∩ B) = 0.3
#
# 다음 보기 중에서 옳은 것을 고르시오.
#
# 1) A와 B는 서로 배반사건이다.
# 2) A와 B는 독립사건이다.
# 3) A와 B는 독립사건이 아니다.

# %%
# Q09 답안을 여기 작성하세요.
# 서술형 풀이 또는 파이썬 코드를 자유롭게 사용해도 됩니다.
