# %% [markdown]
# #### 【 기대값과 분산】<hr>
# <pre>
# 기대값 : 기대값 E[X] = 확률변수의 평균 : 이론적 평균
#         실제 평균(X̄)은 시행 횟수가 늘수록 기대값에 가까워짐.
#
# 분  산 : Var(X)=E[(X−E[X])^2]
#         확률변수 X가 얼마나 불확실하게 퍼져 있는지를 수치로 표현한 값
#         즉, X의 흔들림(변동성)
#         * 분산이 크다 → 값이 넓게 퍼져 있다 → 결과가 불확실
#         * 분산이 작다 → 값이 모여 있다 → 결과가 안정적
#         * 분산이 0   → 항상 같은 값 → 100% 확실
# </pre>

# %%
## ======================================================
## 모듈 로딩
## ======================================================
import random
import numpy as np

# %%
## ======================================================
## 동전 던지기 횟수에 따른 변화 
## ======================================================

##=> 동전: 앞=1, 뒤=0
def toss():
    return random.choice([0,1])


##=> 시도 횟수n번에 따른 평균과 분산 변화
for n in [10, 100, 1000, 10000]:
    data = [toss() for _ in range(n)]
    print(f"{n:>5}번 시행 평균 = {sum(data)/n:.4f}", end=' ')
    print(f"{n:>5}번 분산 = {np.var(data):.4f}")
# Out:
#    10번 시행 평균 = 0.5000    10번 분산 = 0.2500
#   100번 시행 평균 = 0.4900   100번 분산 = 0.2499
#  1000번 시행 평균 = 0.4860  1000번 분산 = 0.2498
# 10000번 시행 평균 = 0.4963 10000번 분산 = 0.2500

# %%
## ======================================================
## 주사위 던지기 횟수에 따른 변화 
## ======================================================

##=> 주사위 1 ~ 6
def roll():
    return random.randint(1, 6)


##=> 시도 횟수n번에 따른 평균과 분산 변화
for n in [10, 100, 1000, 10000]:
    data = [roll() for _ in range(n)]
    print(f"{n:>5}번 시행 평균 = {sum(data)/n:.4f}", end=' ')
    print(f"{n:>5}번 분산 = {np.var(data):.4f}")
# Out:
#    10번 시행 평균 = 3.7000    10번 분산 = 1.6100
#   100번 시행 평균 = 3.7300   100번 분산 = 3.0371
#  1000번 시행 평균 = 3.5020  1000번 분산 = 2.8660
# 10000번 시행 평균 = 3.5097 10000번 분산 = 2.9485
