# %% [markdown]
# #### [PYTHON & MYSQL 연동] <hr>

# %%
## 모듈 로딩
import pymysql

print(f"pymysql v.{pymysql.__version__}")
# Out:
# pymysql v.1.4.6

# %%
## RDBMS 정보
SEVER_IP = 'localhost' 
USER_ID  = 'root'
USER_PW  = 'rlagusdn@0'
DB_NAME  = 'EMS'
CHARSET  = 'uft8mb4'

# %%
## ================================================================
## DB 연결
## ================================================================
conn = pymysql.connect(host        = SEVER_IP,
                       user        = USER_ID,
                       password    = USER_PW,
                       database    = DB_NAME,
                       cursorclass = pymysql.cursors.DictCursor)

# %%
## ================================================================
## DB - SELECT 처리
## ================================================================
ALL_DATA_SQL = 'SELECT * FROM employees;'
ID_DATA_SQL  = 'SELECT id FROM employees'

with conn.cursor() as cursor:
    cursor.execute(ALL_DATA_SQL)
    result = cursor.fetchall()  # 모든 데이터 가져오기
    display(result)
# Out:
# ()

# %%
## ================================================================
## DB - INSERT 처리
## ================================================================
INSERT_DATA_SQL = """
INSERT INTO employees VALUES
(11111, 'password1', '김현우', '대리', 56000000, 15, '개발팀', 'khw274@gmail.com', '010-4738-3936'),
(22222, 'password2', '임정현', '과장', 78000000, 15, '영업팀', '313414@gmail.com', '010-3133-3936'),
(33333, 'password3', '이지연', '사장', 100000000, 15, '구매팀', '1423431@gmail.com', '010-1323-3936'),
(44444, 'password4', '이서범', '부장', 70000000, 15, '부품팀', '32435@gmail.com', '010-4738-5453');
"""

with conn.cursor() as cursor:
    cursor.execute(INSERT_DATA_SQL)
    conn.commit()
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[31], line 653
#       4 INSERT_DATA_SQL = """
#       5 att_id,emp_id,att_date,check_in,check_out,status
#       6 1,10001,2025-01-01,,,결근
#    (...)    649 644,10028,2025-01-31,8:04:00,17:48:00,정상
#     650 """
#     652 with conn.cursor() as cursor:
# --> 653     cursor.execute(INSERT_DATA_SQL)
#     654     conn.commit()
#
# File c:\Users\khw27\anaconda3\envs\DATA311\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File c:\Users\khw27\anaconda3\envs\DATA311\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
# ...

# %%
with conn.cursor() as cursor:
    cursor.execute('ALTER TABLE employees ADD COLUMN email VARCHAR(100), ADD COLUMN phone VARCHAR(20);')
    conn.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[16], line 2
#       1 with conn.cursor() as cursor:
# ----> 2     cursor.execute('ALTER TABLE employees ADD COLUMN email VARCHAR(100), ADD COLUMN phone VARCHAR(20);')
#       3     conn.commit()
#
# File c:\Users\khw27\anaconda3\envs\DATA311\Lib\site-packages\pymysql\cursors.py:153, in Cursor.execute(self, query, args)
#     149     pass
#     151 query = self.mogrify(query, args)
# --> 153 result = self._query(query)
#     154 self._executed = query
#     155 return result
#
# File c:\Users\khw27\anaconda3\envs\DATA311\Lib\site-packages\pymysql\cursors.py:322, in Cursor._query(self, q)
#     320 conn = self._get_db()
#     321 self._clear_result()
# --> 322 conn.query(q)
#     323 self._do_get_result()
#     324 return self.rowcount
#
# ...

# %%
## ================================================================
## DB - DELETE 처리
## ================================================================
DELETE_DATA_SQL = "DELETE FROM employees WHERE emp_id=1;"


with conn.cursor() as cursor:
    cursor.execute(DELETE_DATA_SQL)
    conn.commit()

# %%
## ================================================================
## DB - UPDATE 처리
## ================================================================
UPDATE_DATA_SQL = "UPDATE user SET name=%s WHERE id=%s;"


with conn.cursor() as cursor:
    cursor.execute(UPDATE_DATA_SQL, ('원더우먼', 10))
    conn.commit()

# %%
## ================================================================
## DB 연결 해제
## ================================================================
conn.close()
