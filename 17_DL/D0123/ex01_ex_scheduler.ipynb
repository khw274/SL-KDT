# %% [markdown]
# ### [ Model save & load ]
# - 2가지 형태 저장
#     * 전체 저장
#     * 모델의 파라미터만 저장
# - 2가지 형태 로딩
#     * 전체 저장 모델 파일 ==> 로딩으로 사용 가능
#     * 모델 파라미터 저장 파일 ==> 모델 인스턴스 생성 후 층별 파라미터 적용

# %% [markdown]
# [1] 모듈 로딩 및 데이터 준비<hr>

# %%
## [1-1] 모듈 로딩

import os, sys
sys.path.append(os.path.abspath(".."))

import torch 
import torch.nn as nn 
import torch.nn.functional as F 
import torch.optim as optim 
from   torch.optim.lr_scheduler import ReduceLROnPlateau

from   torch.utils.data import Dataset, TensorDataset, DataLoader
from   torch.utils.data import random_split
from   sklearn.model_selection import train_test_split

from Utils import util_func as uf
import pandas as pd

## 전역 재현성 설정
torch.manual_seed(10)

# %%
## [1-2] 데이터 준비
DATA_FILE = '../Data/study_score_multi.csv'

dataDF    = pd.read_csv(DATA_FILE)
featureDF = dataDF[dataDF.columns[:-1]]
targetDF  = dataDF[dataDF.columns[-1:]]

# %%
## [1-3] 데이터셋 클래스 정의
class TestDataset(Dataset):

    def __init__(self, featureDF, targetDF):
        super().__init__()
        self.xTS = torch.tensor(featureDF.values, dtype=torch.float32)
        self.yTS = torch.tensor(targetDF.values, dtype=torch.float32) 
        self.length = featureDF.shape[0]

    def __len__(self):
        return self.length
    
    def __getitem__(self, idx):
        return self.xTS[idx], self.yTS[idx]

# %%
## 학습용/검증용/테스트용 데이터셋 분리
x_train, x_test, y_train, y_test   = train_test_split(featureDF, targetDF,
                                                      test_size=0.2,
                                                      random_state=10)
x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train,
                                                      test_size=0.2,
                                                      random_state=10)
trainDS  = TestDataset(x_train, y_train)
validDS  = TestDataset(x_valid, y_valid)
testDS   = TestDataset(x_test, y_test)

print(len(trainDS), len(validDS), len(testDS))
# Out:
# 3200 800 1000

# %% [markdown]
# [2] 모델 클래스 정의<hr>

# %%
class Test(nn.Module):
    def __init__(self, in_out, out_out):
        super().__init__()
        self.fc1 = nn.Linear(in_out, 5)
        self.fc2 = nn.Linear(5, 7)
        self.out = nn.Linear(7, out_out)

    def forward(self, x):
        out = F.relu(self.fc1(x))
        out = F.relu(self.fc2(out))
        return self.out(out)

# %% [markdown]
# [3] 학습 진행<hr>

# %%
## 설정값들 
EPOCHS = 1000
BS = 500
LR = 0.1

## 저장 모델 파일명  => 
ALL_MODEL     = '../Models/RegScore_model.pt'    ## 모델 전체 확장자    pt
WEIGHTS_MODEL = '../Models/RegScore_weights'     ## 파라미터 저장 확장자 pth

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# %%
## 인스턴스들
from torchmetrics.regression import R2Score, MeanAbsoluteError, MeanSquaredError 
from torchmetrics.classification import F1Score, Recall
model       = Test(3, 1).to(DEVICE)
loss_fn     = nn.MSELoss()
matrics_fn  = R2Score() 
optimizer   = optim.Adam(model.parameters(), lr= LR)

trainDL     = DataLoader(trainDS, batch_size=BS, shuffle=True)
validDL     = DataLoader(validDS, batch_size=BS) 
testDL      = DataLoader(testDS,  batch_size=BS)

## 스케쥴러 : 검증데이터의 성능지표에 대한 기준 loss, acc
scheduler   = ReduceLROnPlateau(optimizer, mode='min', patience=3)

# %%
## 학습진행 =========================
BEST_LOSS       = 100.
EARLY_STOP_CNT  = 10

for epoch in range(EPOCHS):
    #- 학습진행
    train_loss, train_r2, train_mae = uf.train_one_epoch_reg(model, trainDL, loss_fn, optimizer, DEVICE)

    #- 검증진행
    valid_loss, valid_r2, valid_mae = uf.evaluate_reg(model, validDL, loss_fn, DEVICE)

    #- 모델과 가중치 파일 저장
    if BEST_LOSS > valid_loss:
        #- 모델 전체 저장
        torch.save(model, ALL_MODEL)
        #- 파라미터만 저장
        torch.save(model.state_dict(), f"./{WEIGHTS_MODEL}_{epoch:03}_{valid_loss:.5f}.pth")
        #- 기준 loss 점수 업데이트
        BEST_LOSS = valid_loss

    #- 에포크마다 스케쥴러에게 검증성능 업데이트 
    scheduler.step(valid_loss)

    #- 학습상태 출력
    print(f"{epoch}_[LOSS] train:valid={train_loss:.5f}:{valid_loss:.5f} ", end=' ')
    print(f"[ACC] train:valid={train_r2:.5f}:{valid_r2:.5f} ")
    print(f"[LR] {scheduler.get_last_lr()[0]:.5f} bad_epochs : {scheduler.num_bad_epochs}")

    #- 조기종료 체크
    if(scheduler.patience == scheduler.num_bad_epochs):
        EARLY_STOP_CNT -= 1
    
    if not EARLY_STOP_CNT: 
        print("성능 개선이 없어 조기종료합니다.")
        break
# Out:
# 0_[LOSS] train:valid=1608.87847:438.62326  [ACC] train:valid=-2.63032:-0.01058
# [LR] 0.10000 bad_epochs : 0
# 1_[LOSS] train:valid=552.87957:305.34132  [ACC] train:valid=-0.24753:0.29650
# [LR] 0.10000 bad_epochs : 0
# 2_[LOSS] train:valid=277.87538:205.40114  [ACC] train:valid=0.37299:0.52676
# [LR] 0.10000 bad_epochs : 0
# 3_[LOSS] train:valid=146.43783:115.61910  [ACC] train:valid=0.66957:0.73362
# [LR] 0.10000 bad_epochs : 0
# 4_[LOSS] train:valid=95.38910:77.29597  [ACC] train:valid=0.78476:0.82191
# [LR] 0.10000 bad_epochs : 0
# 5_[LOSS] train:valid=72.80601:65.34951  [ACC] train:valid=0.83572:0.84944
# [LR] 0.10000 bad_epochs : 0
# 6_[LOSS] train:valid=55.19903:48.34573  [ACC] train:valid=0.87545:0.88861
# [LR] 0.10000 bad_epochs : 0
# 7_[LOSS] train:valid=46.59577:47.57514  [ACC] train:valid=0.89486:0.89039
# [LR] 0.10000 bad_epochs : 0
# 8_[LOSS] train:valid=41.24207:40.17885  [ACC] train:valid=0.90694:0.90743
# [LR] 0.10000 bad_epochs : 0
# 9_[LOSS] train:valid=38.85788:39.27092  [ACC] train:valid=0.91232:0.90952
# [LR] 0.10000 bad_epochs : 0
# 10_[LOSS] train:valid=37.17027:38.70541  [ACC] train:valid=0.91613:0.91082
# [LR] 0.10000 bad_epochs : 0
# 11_[LOSS] train:valid=37.12325:39.89550  [ACC] train:valid=0.91623:0.90808
# [LR] 0.10000 bad_epochs : 1
# 12_[LOSS] train:valid=37.07608:38.80502  [ACC] train:valid=0.91634:0.91059
# [LR] 0.10000 bad_epochs : 2
# 13_[LOSS] train:valid=36.95365:38.88795  [ACC] train:valid=0.91662:0.91040
# [LR] 0.10000 bad_epochs : 3
# 14_[LOSS] train:valid=37.01767:39.05874  [ACC] train:valid=0.91647:0.91001
# [LR] 0.01000 bad_epochs : 0
# 15_[LOSS] train:valid=36.92296:38.92033  [ACC] train:valid=0.91669:0.91033
# [LR] 0.01000 bad_epochs : 1
# 16_[LOSS] train:valid=36.94297:38.71258  [ACC] train:valid=0.91664:0.91081
# [LR] 0.01000 bad_epochs : 2
# 17_[LOSS] train:valid=36.89172:39.00000  [ACC] train:valid=0.91676:0.91014
# [LR] 0.01000 bad_epochs : 3
# 18_[LOSS] train:valid=36.94231:39.06496  [ACC] train:valid=0.91664:0.91000
# [LR] 0.00100 bad_epochs : 0
# 19_[LOSS] train:valid=36.91133:38.99962  [ACC] train:valid=0.91671:0.91015
# [LR] 0.00100 bad_epochs : 1
# 20_[LOSS] train:valid=36.89033:38.95042  [ACC] train:valid=0.91676:0.91026
# [LR] 0.00100 bad_epochs : 2
# 21_[LOSS] train:valid=36.88622:38.89168  [ACC] train:valid=0.91677:0.91039
# [LR] 0.00100 bad_epochs : 3
# 22_[LOSS] train:valid=36.87659:38.86764  [ACC] train:valid=0.91679:0.91045
# [LR] 0.00010 bad_epochs : 0
# 23_[LOSS] train:valid=36.87674:38.86599  [ACC] train:valid=0.91679:0.91045
# [LR] 0.00010 bad_epochs : 1
# 24_[LOSS] train:valid=36.87683:38.86566  [ACC] train:valid=0.91679:0.91045
# [LR] 0.00010 bad_epochs : 2
# 25_[LOSS] train:valid=36.87692:38.86329  [ACC] train:valid=0.91679:0.91046
# [LR] 0.00010 bad_epochs : 3
# 26_[LOSS] train:valid=36.87678:38.86448  [ACC] train:valid=0.91679:0.91046
# [LR] 0.00001 bad_epochs : 0
# 27_[LOSS] train:valid=36.87668:38.86439  [ACC] train:valid=0.91679:0.91046
# [LR] 0.00001 bad_epochs : 1
# 28_[LOSS] train:valid=36.87668:38.86434  [ACC] train:valid=0.91679:0.91046
# [LR] 0.00001 bad_epochs : 2
# 29_[LOSS] train:valid=36.87667:38.86443  [ACC] train:valid=0.91679:0.91046
# [LR] 0.00001 bad_epochs : 3
# 30_[LOSS] train:valid=36.87667:38.86440  [ACC] train:valid=0.91679:0.91046
# [LR] 0.00000 bad_epochs : 0
# 31_[LOSS] train:valid=36.87666:38.86440  [ACC] train:valid=0.91679:0.91046
# [LR] 0.00000 bad_epochs : 1
# 32_[LOSS] train:valid=36.87666:38.86442  [ACC] train:valid=0.91679:0.91046
# [LR] 0.00000 bad_epochs : 2
# 33_[LOSS] train:valid=36.87666:38.86442  [ACC] train:valid=0.91679:0.91046
# [LR] 0.00000 bad_epochs : 3
# 34_[LOSS] train:valid=36.87666:38.86443  [ACC] train:valid=0.91679:0.91046
# [LR] 0.00000 bad_epochs : 0
# 35_[LOSS] train:valid=36.87666:38.86444  [ACC] train:valid=0.91679:0.91046
# [LR] 0.00000 bad_epochs : 1
# 36_[LOSS] train:valid=36.87666:38.86444  [ACC] train:valid=0.91679:0.91046
# [LR] 0.00000 bad_epochs : 2
# 37_[LOSS] train:valid=36.87666:38.86444  [ACC] train:valid=0.91679:0.91046
# [LR] 0.00000 bad_epochs : 3
# 38_[LOSS] train:valid=36.87666:38.86444  [ACC] train:valid=0.91679:0.91046
# [LR] 0.00000 bad_epochs : 0
# 39_[LOSS] train:valid=36.87666:38.86444  [ACC] train:valid=0.91679:0.91046
# [LR] 0.00000 bad_epochs : 1
# 40_[LOSS] train:valid=36.87666:38.86444  [ACC] train:valid=0.91679:0.91046
# [LR] 0.00000 bad_epochs : 2
# 41_[LOSS] train:valid=36.87666:38.86444  [ACC] train:valid=0.91679:0.91046
# [LR] 0.00000 bad_epochs : 3
# 42_[LOSS] train:valid=36.87666:38.86444  [ACC] train:valid=0.91679:0.91046
# [LR] 0.00000 bad_epochs : 0
# 43_[LOSS] train:valid=36.87666:38.86444  [ACC] train:valid=0.91679:0.91046
# [LR] 0.00000 bad_epochs : 1
# 44_[LOSS] train:valid=36.87666:38.86444  [ACC] train:valid=0.91679:0.91046
# [LR] 0.00000 bad_epochs : 2
# 45_[LOSS] train:valid=36.87666:38.86444  [ACC] train:valid=0.91679:0.91046
# [LR] 0.00000 bad_epochs : 3
# 46_[LOSS] train:valid=36.87666:38.86444  [ACC] train:valid=0.91679:0.91046
# [LR] 0.00000 bad_epochs : 0
# 47_[LOSS] train:valid=36.87666:38.86444  [ACC] train:valid=0.91679:0.91046
# [LR] 0.00000 bad_epochs : 1
# 48_[LOSS] train:valid=36.87666:38.86444  [ACC] train:valid=0.91679:0.91046
# [LR] 0.00000 bad_epochs : 2
# 49_[LOSS] train:valid=36.87666:38.86444  [ACC] train:valid=0.91679:0.91046
# [LR] 0.00000 bad_epochs : 3
# 성능 개선이 없어 조기종료합니다.

# %% [markdown]
# [4] 모델 파일 사용 <hr>

# %%
## [4-1] 가중치 저장 파일 로딩
params = torch.load("./weights_004_0.18401.pth", weights_only=True)

tModel = Test()
tModel.load_state_dict(params)

# %%
## [4-2] 전체 모델 저장 파일 로딩
allModel = torch.load(ALL_MODEL, weights_only=False)
allModel
