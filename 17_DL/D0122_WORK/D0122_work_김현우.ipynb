# %% [markdown]
# [26_01_22_과제]
# - 알파벳을 사용하는 언어는 알파벳 빈도의 차이로 언어를 식별할 수 있습니다.
# - 해당 데이터셋을 활용해서 언어 식별 모델을 생성하세요.
# - 데이터셋
#   * train 폴더 =>  나라영문2글자-숫자.txt
#   * test 폴더  =>  나라영문2글자-숫자.txt
#
# - 데이터셋 부족 시 Wikipedia 사이트에서 추가 가능 합니다.

# %% [markdown]
# [0] txt -> csv 변환 <hr>
# 문장들의 알파벳 별 빈도수 즉 비율로 csv 파일 저장

# %%
# from txt_csv import *
# csv_data('./dataset/train/', 'train.csv')
# csv_data('./dataset/test/', 'test.csv')

# %% [markdown]
# [1] 모듈 로딩 및 데이터 준비 <hr>

# %%
# ================================================================================
# [1-1] 모듈 로딩
# ================================================================================
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torch.utils.data import Dataset, DataLoader, Subset
from sklearn.model_selection import train_test_split

import pandas as pd
import numpy as np

import util_func as uf 

# ================================================================================
# [1-2] 데이터 준비
# ================================================================================
trainDF = pd.read_csv("./dataset/train.csv")
testDF = pd.read_csv("./dataset/test.csv")

display(trainDF.head())
print(f"Train shape: {trainDF.shape}, Test shape: {testDF.shape}")
# Out:
#    filename language       a       b       c       d       e       f       g  \
# 0  en-1.txt       en  0.0760  0.0128  0.0457  0.0461  0.1053  0.0157  0.0192
# 1  en-2.txt       en  0.0840  0.0199  0.0303  0.0388  0.1367  0.0174  0.0312
# 2  en-3.txt       en  0.0716  0.0122  0.0456  0.0326  0.1201  0.0147  0.0252
# 3  en-4.txt       en  0.0720  0.0276  0.0299  0.0395  0.1207  0.0167  0.0235
# 4  en-5.txt       en  0.0738  0.0204  0.0311  0.0396  0.1413  0.0204  0.0204
#
#         h  ...       q       r       s       t       u       v       w  \
# 0  0.0437  ...  0.0000  0.0777  0.0614  0.0805  0.0259  0.0098  0.0141
# 1  0.0274  ...  0.0055  0.0899  0.0715  0.0776  0.0306  0.0137  0.0139
# 2  0.0235  ...  0.0017  0.0539  0.0880  0.0811  0.0290  0.0188  0.0119
# 3  0.0588  ...  0.0004  0.0590  0.0731  0.0934  0.0242  0.0051  0.0195
# 4  0.0569  ...  0.0004  0.0725  0.0596  0.0955  0.0250  0.0107  0.0239
#
#         x       y       z
# 0  0.0007  0.0200  0.0004
# 1  0.0020  0.0107  0.0006
# 2  0.0006  0.0180  0.0006
# 3  0.0060  0.0175  0.0017
# 4  0.0031  0.0149  0.0007
#
# [5 rows x 28 columns]
# Train shape: (20, 28), Test shape: (8, 28)

# %% [markdown]
# [2] 커스텀 Dataset 클래스 <hr>

# %%
# ================================================================================
# [2-1] 커스텀 데이터셋 클래스 정의
# ================================================================================
# 클래스이름 : LangDataset
# 부모클래스 : Dataset
# 오버라이딩 : __init__()
#            __len__()
#            __getitem__()
# ================================================================================
class LangDataset(Dataset):
    
    def __init__(self, dataDF):
        super().__init__()

        self.x = dataDF[dataDF.columns[2:]].values  # 피쳐

        targetDict = {"en":0, "fr":1, "id":2, "tl":3}
        self.y = dataDF[dataDF.columns[1]].map(targetDict).values.astype(np.int64)
        # self.y = dataDF[dataDF.columns[1]].values   # 타겟

    def __len__(self):
        return self.x.shape[0] # 행수
    
    # 인덱스에 해당하는 피쳐와 타겟 텐서 반환 메서드
    def __getitem__(self, index):
        xTS = torch.tensor(self.x[index], dtype = torch.float32)
        yTS = torch.tensor(self.y[index])

        return xTS, yTS

# %%
# ================================================================================
# [2-2] 커스텀 데이터셋 인스턴스 생성 및 사용
# ================================================================================
allDS  = LangDataset(trainDF)
testDS = LangDataset(testDF)

print(f"allDS : {len(allDS)}, testDS : {len(testDS)}")
# Out:
# allDS : 20, testDS : 8

# %%
# ================================================================================
# [2-3] 학습용/검증용/테스트용 데이터셋 분리
# ================================================================================
# 학습용 데이터셋에서 타겟/라벨만 추출 
targetList = allDS.y

# 전체 데이터 인덱스 리스트 생성
dataIndexList = list(range(len(allDS)))

# 학습용/검증용 데이터셋 인덱스 분리
x_trainIdx, x_validIdx, y_train, y_valid = train_test_split(
    dataIndexList,
    targetList,
    stratify=targetList,
    train_size=0.8,
    random_state=10)

# %%
# ================================================================================
# [2-4] 학습용/검증용 데이터셋 생성 ===> Dataset ==> 2개 Subset 분리
# ================================================================================
trainDS = Subset(allDS, x_trainIdx)
validDS = Subset(allDS, x_validIdx)

print(f"allDS : {len(allDS)}, trainDS : {len(trainDS)}, validDS : {len(validDS)}, testDS : {len(testDS)}")
# Out:
# allDS : 20, trainDS : 16, validDS : 4, testDS : 8

# %% [markdown]
# [3] 모델 클래스 설계 <hr>

# %%
# ================================================================================
# [3-1] 커스텀 모델 클래스 정의
# ================================================================================
#               입력                출력               활성화함수
# 입력층          26                 26                 
# 은닉층1         26                128                  ReLU
# 은닉층2        128                 64                  ReLU
# 은닉층3         64                 32                  ReLU
# 출력층          32                  1                   -      Pytorch의 다중분류 손실함수 중
#                                                               CrossEntropyLoss는 내부에서 softmax 처리 진행
#                                                               출력층에서 softmax 활성함수 필요 없음!
# ================================================================================
# 클래스이름 : LangModel
# 부모클래스 : nn.module
# 오버라이딩 : __init()
#            forward()
# ================================================================================
class LangModel(nn.Module):

    def __init__(self, in_, out_, hd1, hd2, hd3):
        
        # 인공신경망(ANN) 구성
        super().__init__()
        self.hd1_layer = nn.Linear(in_, hd1)
        self.hd2_layer = nn.Linear(hd1, hd2)
        self.hd3_layer = nn.Linear(hd2, hd3)
        self.out_layer = nn.Linear(hd3, out_)

    def forward(self, data):

        # 입력층  -> 은닉층1
        out = F.relu(self.hd1_layer(data))

        # 은닉층1 -> 은닉층2
        out = F.relu(self.hd2_layer(out))

        # 은닉층2 -> 은닉층3
        out = F.relu(self.hd3_layer(out))

        # 은닉층3 -> 출력층
        out = self.out_layer(out)

        return out

# %%
# ================================================================================
# [3-2] 커스텀 모델 클래스 구조 확인
# ================================================================================
from torchinfo import summary
summary(LangModel(in_=26, out_=4, hd1=128, hd2=64, hd3=32),
        input_size=(1, 26))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# LangModel                                [1, 4]                    --
# ├─Linear: 1-1                            [1, 128]                  3,456
# ├─Linear: 1-2                            [1, 64]                   8,256
# ├─Linear: 1-3                            [1, 32]                   2,080
# ├─Linear: 1-4                            [1, 4]                    132
# ==========================================================================================
# Total params: 13,924
# Trainable params: 13,924
# Non-trainable params: 0
# Total mult-adds (M): 0.01
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.06
# Estimated Total Size (MB): 0.06
# ==========================================================================================

# %% [markdown]
# [4] 학습 준비<hr>

# %%
# ================================================================================
# [4-1] 학습 관련 설정
# ================================================================================
EPOCHS      = 100
BATCH_SIZE  = 2
LR          = 0.01
DEVICE      = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
# ================================================================================
# [4-2] 학습 관련 인스턴스 생성
# ================================================================================
# 모델 인스턴스
model = LangModel(in_=26, out_=4, hd1=128, hd2=64, hd3=32).to(DEVICE)

# 손실함수 인스턴스 : 다중분류용
lossFN = nn.CrossEntropyLoss()

# 최적화 인스턴스
optimizer = optim.Adam(model.parameters(), lr=LR)

# 데이터로더 인스턴스
trainDL = DataLoader(trainDS, batch_size=BATCH_SIZE, shuffle=True)
validDL = DataLoader(validDS, batch_size=BATCH_SIZE)
testDL = DataLoader(testDS, batch_size=BATCH_SIZE)

# %% [markdown]
# [5] 학습 진행 <HR>

# %%
HISTORY = {
    'train_loss': [],       # 학습 손실값 (작을수록 좋음)
    'train_acc' : [],       # 학습 정확도 (클수록 좋음)
    'val_loss'  : [],       # 검증 손실값 (작을수록 좋음)
    'val_acc'   : []        # 검증 정확도 (클수록 좋음)
}

for epoch in range(EPOCHS):
    # 1에포크 학습
    train_loss, train_acc = uf.train_one_epoch(
        model, 
        trainDL, 
        lossFN, 
        optimizer,
        DEVICE)

    # 1에포크 학습 후 업데이트 W, b 검사
    val_loss, val_acc = uf.evaluate(model, validDL, lossFN, DEVICE)

    # 학습과 검증 결과 저장 
    HISTORY['train_loss'].append(train_loss)
    HISTORY['train_acc'].append(train_acc)
    HISTORY['val_loss'].append(val_loss)
    HISTORY['val_acc'].append(val_acc)


    # 진행 상황 출력
    print( f'[EPOCH-{epoch:03}] LOSS => Train : {train_loss:.7f}  Valid : {val_loss:.7f}  Acc => Train : {train_acc:.5f}' , end='')
    print( f'  Valid : {val_acc:.5f}' )
# Out:
# [EPOCH-000] LOSS => Train : 1.4261493  Valid : 1.3883697  Acc => Train : 0.18750  Valid : 0.25000
# [EPOCH-001] LOSS => Train : 1.3954329  Valid : 1.3883221  Acc => Train : 0.25000  Valid : 0.25000
# [EPOCH-002] LOSS => Train : 1.3905839  Valid : 1.3874298  Acc => Train : 0.25000  Valid : 0.25000
# [EPOCH-003] LOSS => Train : 1.3905529  Valid : 1.3868575  Acc => Train : 0.12500  Valid : 0.25000
# [EPOCH-004] LOSS => Train : 1.3899816  Valid : 1.3856635  Acc => Train : 0.12500  Valid : 0.25000
# [EPOCH-005] LOSS => Train : 1.3952924  Valid : 1.3844776  Acc => Train : 0.12500  Valid : 0.25000
# [EPOCH-006] LOSS => Train : 1.3875628  Valid : 1.3830166  Acc => Train : 0.12500  Valid : 0.25000
# [EPOCH-007] LOSS => Train : 1.3846449  Valid : 1.3781849  Acc => Train : 0.25000  Valid : 0.25000
# [EPOCH-008] LOSS => Train : 1.3748786  Valid : 1.3553484  Acc => Train : 0.25000  Valid : 0.75000
# [EPOCH-009] LOSS => Train : 1.3643704  Valid : 1.2958326  Acc => Train : 0.37500  Valid : 0.50000
# [EPOCH-010] LOSS => Train : 1.2498172  Valid : 1.1158407  Acc => Train : 0.50000  Valid : 0.50000
# [EPOCH-011] LOSS => Train : 1.0290339  Valid : 0.8467458  Acc => Train : 0.50000  Valid : 0.50000
# [EPOCH-012] LOSS => Train : 0.8496149  Valid : 0.7320725  Acc => Train : 0.50000  Valid : 0.50000
# [EPOCH-013] LOSS => Train : 0.8394509  Valid : 0.6952773  Acc => Train : 0.25000  Valid : 0.75000
# [EPOCH-014] LOSS => Train : 0.7043506  Valid : 0.5966351  Acc => Train : 0.62500  Valid : 0.50000
# [EPOCH-015] LOSS => Train : 0.6640394  Valid : 1.1483712  Acc => Train : 0.43750  Valid : 0.50000
# [EPOCH-016] LOSS => Train : 0.6940346  Valid : 0.6903550  Acc => Train : 0.62500  Valid : 0.50000
# [EPOCH-017] LOSS => Train : 0.7577501  Valid : 0.6400169  Acc => Train : 0.43750  Valid : 0.50000
# [EPOCH-018] LOSS => Train : 0.7229698  Valid : 1.2566468  Acc => Train : 0.50000  Valid : 0.25000
# [EPOCH-019] LOSS => Train : 0.7405508  Valid : 0.6344118  Acc => Train : 0.37500  Valid : 0.50000
# [EPOCH-020] LOSS => Train : 0.7564674  Valid : 0.6175570  Acc => Train : 0.62500  Valid : 0.75000
# [EPOCH-021] LOSS => Train : 0.7391722  Valid : 0.5805041  Acc => Train : 0.43750  Valid : 0.75000
# [EPOCH-022] LOSS => Train : 0.6724942  Valid : 0.8681735  Acc => Train : 0.62500  Valid : 0.50000
# [EPOCH-023] LOSS => Train : 0.6166342  Valid : 0.6573263  Acc => Train : 0.62500  Valid : 0.50000
# [EPOCH-024] LOSS => Train : 0.6148836  Valid : 0.5319473  Acc => Train : 0.56250  Valid : 0.75000
# [EPOCH-025] LOSS => Train : 0.5637570  Valid : 0.4833608  Acc => Train : 0.75000  Valid : 0.75000
# [EPOCH-026] LOSS => Train : 0.5490643  Valid : 0.3918502  Acc => Train : 0.68750  Valid : 0.75000
# [EPOCH-027] LOSS => Train : 0.6498214  Valid : 0.4459686  Acc => Train : 0.62500  Valid : 0.75000
# [EPOCH-028] LOSS => Train : 0.7323476  Valid : 0.4234297  Acc => Train : 0.56250  Valid : 0.75000
# [EPOCH-029] LOSS => Train : 0.4933116  Valid : 0.7640272  Acc => Train : 0.68750  Valid : 0.50000
# [EPOCH-030] LOSS => Train : 0.4918375  Valid : 0.4414564  Acc => Train : 0.62500  Valid : 0.75000
# [EPOCH-031] LOSS => Train : 0.4906248  Valid : 0.3909020  Acc => Train : 0.68750  Valid : 0.75000
# [EPOCH-032] LOSS => Train : 0.4448568  Valid : 0.5525924  Acc => Train : 0.75000  Valid : 0.75000
# [EPOCH-033] LOSS => Train : 0.4934503  Valid : 0.4113355  Acc => Train : 0.68750  Valid : 0.75000
# [EPOCH-034] LOSS => Train : 0.4273892  Valid : 0.4634356  Acc => Train : 0.68750  Valid : 0.75000
# [EPOCH-035] LOSS => Train : 0.4025958  Valid : 0.3800030  Acc => Train : 0.75000  Valid : 0.75000
# [EPOCH-036] LOSS => Train : 0.3849790  Valid : 0.4384609  Acc => Train : 0.75000  Valid : 0.75000
# [EPOCH-037] LOSS => Train : 0.3786382  Valid : 0.3790015  Acc => Train : 0.75000  Valid : 0.75000
# [EPOCH-038] LOSS => Train : 0.4014776  Valid : 0.3678911  Acc => Train : 0.75000  Valid : 0.75000
# [EPOCH-039] LOSS => Train : 0.4454413  Valid : 0.4307280  Acc => Train : 0.62500  Valid : 0.75000
# [EPOCH-040] LOSS => Train : 0.4214233  Valid : 0.3575328  Acc => Train : 0.75000  Valid : 1.00000
# [EPOCH-041] LOSS => Train : 0.3555769  Valid : 0.9359791  Acc => Train : 0.75000  Valid : 0.50000
# [EPOCH-042] LOSS => Train : 0.4755330  Valid : 0.3452051  Acc => Train : 0.68750  Valid : 0.75000
# [EPOCH-043] LOSS => Train : 0.4285617  Valid : 0.5342974  Acc => Train : 0.68750  Valid : 0.75000
# [EPOCH-044] LOSS => Train : 0.6072033  Valid : 0.3599537  Acc => Train : 0.68750  Valid : 1.00000
# [EPOCH-045] LOSS => Train : 0.5475050  Valid : 0.3359140  Acc => Train : 0.62500  Valid : 0.75000
# [EPOCH-046] LOSS => Train : 0.4000820  Valid : 0.3442910  Acc => Train : 0.75000  Valid : 0.75000
# [EPOCH-047] LOSS => Train : 0.3648036  Valid : 0.3301990  Acc => Train : 0.75000  Valid : 0.75000
# [EPOCH-048] LOSS => Train : 0.3257383  Valid : 0.3260781  Acc => Train : 0.93750  Valid : 0.75000
# [EPOCH-049] LOSS => Train : 0.3015400  Valid : 0.2986188  Acc => Train : 0.93750  Valid : 1.00000
# [EPOCH-050] LOSS => Train : 0.2694887  Valid : 0.2851064  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-051] LOSS => Train : 0.2117211  Valid : 0.2655998  Acc => Train : 0.93750  Valid : 0.75000
# [EPOCH-052] LOSS => Train : 0.2092015  Valid : 0.2336695  Acc => Train : 1.00000  Valid : 0.75000
# [EPOCH-053] LOSS => Train : 0.1578546  Valid : 0.1121604  Acc => Train : 0.93750  Valid : 1.00000
# [EPOCH-054] LOSS => Train : 0.1013580  Valid : 0.3238671  Acc => Train : 1.00000  Valid : 0.75000
# [EPOCH-055] LOSS => Train : 0.1294894  Valid : 0.1047385  Acc => Train : 0.93750  Valid : 1.00000
# [EPOCH-056] LOSS => Train : 0.1057872  Valid : 0.0665113  Acc => Train : 0.93750  Valid : 1.00000
# [EPOCH-057] LOSS => Train : 0.0201913  Valid : 0.2570943  Acc => Train : 1.00000  Valid : 0.75000
# [EPOCH-058] LOSS => Train : 0.0169149  Valid : 0.1519345  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-059] LOSS => Train : 0.0108071  Valid : 0.1156323  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-060] LOSS => Train : 0.0087038  Valid : 0.1013487  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-061] LOSS => Train : 0.0071840  Valid : 0.1157892  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-062] LOSS => Train : 0.0063569  Valid : 0.1590201  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-063] LOSS => Train : 0.0054352  Valid : 0.1333929  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-064] LOSS => Train : 0.0048334  Valid : 0.1025938  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-065] LOSS => Train : 0.0037760  Valid : 0.1491660  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-066] LOSS => Train : 0.0035122  Valid : 0.1074689  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-067] LOSS => Train : 0.0029946  Valid : 0.0668629  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-068] LOSS => Train : 0.0025896  Valid : 0.1059688  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-069] LOSS => Train : 0.0024149  Valid : 0.1386761  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-070] LOSS => Train : 0.0022270  Valid : 0.1123565  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-071] LOSS => Train : 0.0019587  Valid : 0.1005961  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-072] LOSS => Train : 0.0018516  Valid : 0.0837096  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-073] LOSS => Train : 0.0019683  Valid : 0.1437279  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-074] LOSS => Train : 0.0015834  Valid : 0.0937690  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-075] LOSS => Train : 0.0014898  Valid : 0.0782339  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-076] LOSS => Train : 0.0013212  Valid : 0.0812228  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-077] LOSS => Train : 0.0012161  Valid : 0.0907318  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-078] LOSS => Train : 0.0012036  Valid : 0.1190084  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-079] LOSS => Train : 0.0011481  Valid : 0.0918116  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-080] LOSS => Train : 0.0010607  Valid : 0.0835430  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-081] LOSS => Train : 0.0010029  Valid : 0.0924169  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-082] LOSS => Train : 0.0009815  Valid : 0.1125199  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-083] LOSS => Train : 0.0009165  Valid : 0.0862911  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-084] LOSS => Train : 0.0008771  Valid : 0.0985922  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-085] LOSS => Train : 0.0007971  Valid : 0.0831002  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-086] LOSS => Train : 0.0007784  Valid : 0.0906028  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-087] LOSS => Train : 0.0007225  Valid : 0.0779110  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-088] LOSS => Train : 0.0006940  Valid : 0.0825606  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-089] LOSS => Train : 0.0006678  Valid : 0.0923704  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-090] LOSS => Train : 0.0006708  Valid : 0.0758032  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-091] LOSS => Train : 0.0006575  Valid : 0.0944172  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-092] LOSS => Train : 0.0005890  Valid : 0.0884634  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-093] LOSS => Train : 0.0005590  Valid : 0.0765727  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-094] LOSS => Train : 0.0005524  Valid : 0.0726996  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-095] LOSS => Train : 0.0005182  Valid : 0.0797492  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-096] LOSS => Train : 0.0005307  Valid : 0.0844941  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-097] LOSS => Train : 0.0004844  Valid : 0.0752295  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-098] LOSS => Train : 0.0004659  Valid : 0.0724912  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-099] LOSS => Train : 0.0004580  Valid : 0.0877719  Acc => Train : 1.00000  Valid : 1.00000

# %% [markdown]
# [6] 시각화 <hr>

# %%
uf.plot_history(HISTORY)
