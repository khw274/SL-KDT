# %% [markdown]
# [26_01_22_과제]
# - 알파벳을 사용하는 언어는 알파벳 빈도의 차이로 언어를 식별할 수 있습니다.
# - 해당 데이터셋을 활용해서 언어 식별 모델을 생성하세요.
# - 데이터셋
#   * train 폴더 =>  나라영문2글자-숫자.txt
#   * test 폴더  =>  나라영문2글자-숫자.txt
#
# - 데이터셋 부족 시 Wikipedia 사이트에서 추가 가능 합니다.

# %% [markdown]
# [0] txt -> csv 변환 <hr>
# 문장들의 알파벳 별 빈도수 즉 비율로 csv 파일 저장

# %%
# from txt_csv import *
# csv_data('./dataset/train/', 'train.csv')
# csv_data('./dataset/test/', 'test.csv')

# %% [markdown]
# [1] 모듈 로딩 및 데이터 준비 <hr>

# %%
# ================================================================================
# [1-1] 모듈 로딩
# ================================================================================
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from torch.utils.data import Dataset, DataLoader, Subset
from sklearn.model_selection import train_test_split

import pandas as pd
import numpy as np

import util_func as uf 

# ================================================================================
# [1-2] 데이터 준비
# ================================================================================
trainDF = pd.read_csv("./dataset/train.csv")
testDF = pd.read_csv("./dataset/test.csv")

display(trainDF.head())
print(f"Train shape: {trainDF.shape}, Test shape: {testDF.shape}")
# Out:
#    filename language       a       b       c       d       e       f       g  \
# 0  en-1.txt       en  0.0760  0.0128  0.0457  0.0461  0.1053  0.0157  0.0192
# 1  en-2.txt       en  0.0840  0.0199  0.0303  0.0388  0.1367  0.0174  0.0312
# 2  en-3.txt       en  0.0716  0.0122  0.0456  0.0326  0.1201  0.0147  0.0252
# 3  en-4.txt       en  0.0720  0.0276  0.0299  0.0395  0.1207  0.0167  0.0235
# 4  en-5.txt       en  0.0738  0.0204  0.0311  0.0396  0.1413  0.0204  0.0204
#
#         h  ...       q       r       s       t       u       v       w  \
# 0  0.0437  ...  0.0000  0.0777  0.0614  0.0805  0.0259  0.0098  0.0141
# 1  0.0274  ...  0.0055  0.0899  0.0715  0.0776  0.0306  0.0137  0.0139
# 2  0.0235  ...  0.0017  0.0539  0.0880  0.0811  0.0290  0.0188  0.0119
# 3  0.0588  ...  0.0004  0.0590  0.0731  0.0934  0.0242  0.0051  0.0195
# 4  0.0569  ...  0.0004  0.0725  0.0596  0.0955  0.0250  0.0107  0.0239
#
#         x       y       z
# 0  0.0007  0.0200  0.0004
# 1  0.0020  0.0107  0.0006
# 2  0.0006  0.0180  0.0006
# 3  0.0060  0.0175  0.0017
# 4  0.0031  0.0149  0.0007
#
# [5 rows x 28 columns]
# Train shape: (20, 28), Test shape: (8, 28)

# %% [markdown]
# [2] 커스텀 Dataset 클래스 <hr>

# %%
# ================================================================================
# [2-1] 커스텀 데이터셋 클래스 정의
# ================================================================================
# 클래스이름 : LangDataset
# 부모클래스 : Dataset
# 오버라이딩 : __init__()
#            __len__()
#            __getitem__()
# ================================================================================
class LangDataset(Dataset):
    
    def __init__(self, dataDF):
        super().__init__()

        self.x = dataDF[dataDF.columns[2:]].values  # 피쳐

        targetDict = {"en":0, "fr":1, "id":2, "tl":3}
        self.y = dataDF[dataDF.columns[1]].map(targetDict).values.astype(np.int64)
        # self.y = dataDF[dataDF.columns[1]].values   # 타겟

    def __len__(self):
        return self.x.shape[0] # 행수
    
    # 인덱스에 해당하는 피쳐와 타겟 텐서 반환 메서드
    def __getitem__(self, index):
        xTS = torch.tensor(self.x[index], dtype = torch.float32)
        yTS = torch.tensor(self.y[index])

        return xTS, yTS

# %%
# ================================================================================
# [2-2] 커스텀 데이터셋 인스턴스 생성 및 사용
# ================================================================================
allDS  = LangDataset(trainDF)
testDS = LangDataset(testDF)

print(f"allDS : {len(allDS)}, testDS : {len(testDS)}")
# Out:
# allDS : 20, testDS : 8

# %%
# ================================================================================
# [2-3] 학습용/검증용/테스트용 데이터셋 분리
# ================================================================================
# 학습용 데이터셋에서 타겟/라벨만 추출 
targetList = allDS.y

# 전체 데이터 인덱스 리스트 생성
dataIndexList = list(range(len(allDS)))

# 학습용/검증용 데이터셋 인덱스 분리
x_trainIdx, x_validIdx, y_train, y_valid = train_test_split(
    dataIndexList,
    targetList,
    stratify=targetList,
    train_size=0.8,
    random_state=10)

# %%
# ================================================================================
# [2-4] 학습용/검증용 데이터셋 생성 ===> Dataset ==> 2개 Subset 분리
# ================================================================================
trainDS = Subset(allDS, x_trainIdx)
validDS = Subset(allDS, x_validIdx)

print(f"allDS : {len(allDS)}, trainDS : {len(trainDS)}, validDS : {len(validDS)}, testDS : {len(testDS)}")
# Out:
# allDS : 20, trainDS : 16, validDS : 4, testDS : 8

# %% [markdown]
# [3] 모델 클래스 설계 <hr>

# %%
# ================================================================================
# [3-1] 커스텀 모델 클래스 정의
# ================================================================================
#               입력                출력               활성화함수
# 입력층          26                 26                 
# 은닉층1         26                128                  ReLU
# 은닉층2        128                 64                  ReLU
# 은닉층3         64                 32                  ReLU
# 출력층          32                  1                   -      Pytorch의 다중분류 손실함수 중
#                                                               CrossEntropyLoss는 내부에서 softmax 처리 진행
#                                                               출력층에서 softmax 활성함수 필요 없음!
# ================================================================================
# 클래스이름 : LangModel
# 부모클래스 : nn.module
# 오버라이딩 : __init()
#            forward()
# ================================================================================
class LangModel(nn.Module):

    def __init__(self, in_, out_, hd1, hd2, hd3):
        
        # 인공신경망(ANN) 구성
        super().__init__()
        self.hd1_layer = nn.Linear(in_, hd1)
        self.hd2_layer = nn.Linear(hd1, hd2)
        self.hd3_layer = nn.Linear(hd2, hd3)
        self.out_layer = nn.Linear(hd3, out_)

    def forward(self, data):

        # 입력층  -> 은닉층1
        out = F.relu(self.hd1_layer(data))

        # 은닉층1 -> 은닉층2
        out = F.relu(self.hd2_layer(out))

        # 은닉층2 -> 은닉층3
        out = F.relu(self.hd3_layer(out))

        # 은닉층3 -> 출력층
        out = self.out_layer(out)

        return out

# %%
# ================================================================================
# [3-2] 커스텀 모델 클래스 구조 확인
# ================================================================================
from torchinfo import summary
summary(LangModel(in_=26, out_=4, hd1=128, hd2=64, hd3=32),
        input_size=(1, 26))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# LangModel                                [1, 4]                    --
# ├─Linear: 1-1                            [1, 128]                  3,456
# ├─Linear: 1-2                            [1, 64]                   8,256
# ├─Linear: 1-3                            [1, 32]                   2,080
# ├─Linear: 1-4                            [1, 4]                    132
# ==========================================================================================
# Total params: 13,924
# Trainable params: 13,924
# Non-trainable params: 0
# Total mult-adds (M): 0.01
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.06
# Estimated Total Size (MB): 0.06
# ==========================================================================================

# %% [markdown]
# [4] 학습 준비<hr>

# %%
# ================================================================================
# [4-1] 학습 관련 설정
# ================================================================================
EPOCHS      = 100
BATCH_SIZE  = 2
LR          = 0.01
DEVICE      = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
# ================================================================================
# [4-2] 학습 관련 인스턴스 생성
# ================================================================================
# 모델 인스턴스
model = LangModel(in_=26, out_=4, hd1=128, hd2=64, hd3=32).to(DEVICE)

# 손실함수 인스턴스 : 다중분류용
lossFN = nn.CrossEntropyLoss()

# 최적화 인스턴스
optimizer = optim.Adam(model.parameters(), lr=LR)

# 데이터로더 인스턴스
trainDL = DataLoader(trainDS, batch_size=BATCH_SIZE, shuffle=True)
validDL = DataLoader(validDS, batch_size=BATCH_SIZE)
testDL = DataLoader(testDS, batch_size=BATCH_SIZE)

# %% [markdown]
# [5] 학습 진행 <HR>

# %%
HISTORY = {
    'train_loss': [],       # 학습 손실값 (작을수록 좋음)
    'train_acc' : [],       # 학습 정확도 (클수록 좋음)
    'val_loss'  : [],       # 검증 손실값 (작을수록 좋음)
    'val_acc'   : []        # 검증 정확도 (클수록 좋음)
}

for epoch in range(EPOCHS):
    # 1에포크 학습
    train_loss, train_acc = uf.train_one_epoch(
        model, 
        trainDL, 
        lossFN, 
        optimizer,
        DEVICE)

    # 1에포크 학습 후 업데이트 W, b 검사
    val_loss, val_acc = uf.evaluate(model, validDL, lossFN, DEVICE)

    # 학습과 검증 결과 저장 
    HISTORY['train_loss'].append(train_loss)
    HISTORY['train_acc'].append(train_acc)
    HISTORY['val_loss'].append(val_loss)
    HISTORY['val_acc'].append(val_acc)


    # 진행 상황 출력
    print( f'[EPOCH-{epoch:03}] LOSS => Train : {train_loss:.7f}  Valid : {val_loss:.7f}  Acc => Train : {train_acc:.5f}' , end='')
    print( f'  Valid : {val_acc:.5f}' )
# Out:
# [EPOCH-000] LOSS => Train : 1.4032651  Valid : 1.3860016  Acc => Train : 0.25000  Valid : 0.25000
# [EPOCH-001] LOSS => Train : 1.3941332  Valid : 1.3848537  Acc => Train : 0.18750  Valid : 0.25000
# [EPOCH-002] LOSS => Train : 1.3909483  Valid : 1.3811252  Acc => Train : 0.25000  Valid : 0.25000
# [EPOCH-003] LOSS => Train : 1.3872517  Valid : 1.3739392  Acc => Train : 0.25000  Valid : 0.25000
# [EPOCH-004] LOSS => Train : 1.3727407  Valid : 1.3524593  Acc => Train : 0.31250  Valid : 0.50000
# [EPOCH-005] LOSS => Train : 1.3377781  Valid : 1.2824519  Acc => Train : 0.37500  Valid : 0.75000
# [EPOCH-006] LOSS => Train : 1.1943403  Valid : 1.0436077  Acc => Train : 0.50000  Valid : 0.75000
# [EPOCH-007] LOSS => Train : 0.9116165  Valid : 0.7797678  Acc => Train : 0.50000  Valid : 0.75000
# [EPOCH-008] LOSS => Train : 0.7515764  Valid : 0.8202277  Acc => Train : 0.37500  Valid : 0.75000
# [EPOCH-009] LOSS => Train : 1.0110873  Valid : 1.2416580  Acc => Train : 0.43750  Valid : 0.50000
# [EPOCH-010] LOSS => Train : 0.9674232  Valid : 0.7533266  Acc => Train : 0.37500  Valid : 0.75000
# [EPOCH-011] LOSS => Train : 0.7499431  Valid : 0.7970554  Acc => Train : 0.62500  Valid : 0.50000
# [EPOCH-012] LOSS => Train : 0.6995372  Valid : 0.6754616  Acc => Train : 0.50000  Valid : 0.50000
# [EPOCH-013] LOSS => Train : 0.7225507  Valid : 0.6571639  Acc => Train : 0.62500  Valid : 0.50000
# [EPOCH-014] LOSS => Train : 0.6459446  Valid : 0.6341652  Acc => Train : 0.50000  Valid : 0.50000
# [EPOCH-015] LOSS => Train : 0.6434936  Valid : 0.5895377  Acc => Train : 0.62500  Valid : 0.75000
# [EPOCH-016] LOSS => Train : 0.6083526  Valid : 0.5813956  Acc => Train : 0.68750  Valid : 0.50000
# [EPOCH-017] LOSS => Train : 0.6508992  Valid : 0.5252183  Acc => Train : 0.62500  Valid : 0.75000
# [EPOCH-018] LOSS => Train : 0.5943325  Valid : 0.5465792  Acc => Train : 0.62500  Valid : 0.75000
# [EPOCH-019] LOSS => Train : 0.5936622  Valid : 0.5564283  Acc => Train : 0.56250  Valid : 0.75000
# [EPOCH-020] LOSS => Train : 0.5051099  Valid : 0.4515472  Acc => Train : 0.75000  Valid : 1.00000
# [EPOCH-021] LOSS => Train : 0.4795725  Valid : 0.4395800  Acc => Train : 0.81250  Valid : 1.00000
# [EPOCH-022] LOSS => Train : 0.4144293  Valid : 0.4061753  Acc => Train : 0.81250  Valid : 1.00000
# [EPOCH-023] LOSS => Train : 0.4026727  Valid : 0.4096893  Acc => Train : 0.75000  Valid : 1.00000
# [EPOCH-024] LOSS => Train : 0.3840272  Valid : 0.3523300  Acc => Train : 0.87500  Valid : 1.00000
# [EPOCH-025] LOSS => Train : 0.3889792  Valid : 0.4181349  Acc => Train : 0.81250  Valid : 0.75000
# [EPOCH-026] LOSS => Train : 0.3128968  Valid : 0.2889029  Acc => Train : 0.93750  Valid : 1.00000
# [EPOCH-027] LOSS => Train : 0.3822202  Valid : 0.5431094  Acc => Train : 0.75000  Valid : 0.75000
# [EPOCH-028] LOSS => Train : 0.3567812  Valid : 0.1358449  Acc => Train : 0.81250  Valid : 1.00000
# [EPOCH-029] LOSS => Train : 0.2766131  Valid : 0.2424204  Acc => Train : 0.87500  Valid : 1.00000
# [EPOCH-030] LOSS => Train : 0.2426246  Valid : 0.1552190  Acc => Train : 0.87500  Valid : 1.00000
# [EPOCH-031] LOSS => Train : 0.2559180  Valid : 0.0592395  Acc => Train : 0.87500  Valid : 1.00000
# [EPOCH-032] LOSS => Train : 0.3058718  Valid : 1.0645727  Acc => Train : 0.81250  Valid : 0.50000
# [EPOCH-033] LOSS => Train : 0.4730553  Valid : 0.0884228  Acc => Train : 0.75000  Valid : 1.00000
# [EPOCH-034] LOSS => Train : 0.2576633  Valid : 0.0820019  Acc => Train : 0.93750  Valid : 1.00000
# [EPOCH-035] LOSS => Train : 0.1978217  Valid : 0.4194993  Acc => Train : 1.00000  Valid : 0.75000
# [EPOCH-036] LOSS => Train : 0.2489351  Valid : 0.1424268  Acc => Train : 0.87500  Valid : 1.00000
# [EPOCH-037] LOSS => Train : 0.2122558  Valid : 0.4753467  Acc => Train : 0.93750  Valid : 0.75000
# [EPOCH-038] LOSS => Train : 0.1246526  Valid : 0.0276920  Acc => Train : 0.93750  Valid : 1.00000
# [EPOCH-039] LOSS => Train : 0.1113679  Valid : 0.0703204  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-040] LOSS => Train : 0.0732168  Valid : 0.4146374  Acc => Train : 1.00000  Valid : 0.75000
# [EPOCH-041] LOSS => Train : 0.0484175  Valid : 0.1981030  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-042] LOSS => Train : 0.0449553  Valid : 0.0969833  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-043] LOSS => Train : 0.0255435  Valid : 0.1166980  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-044] LOSS => Train : 0.0312424  Valid : 0.0433586  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-045] LOSS => Train : 0.0150281  Valid : 0.0882682  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-046] LOSS => Train : 0.0152935  Valid : 0.0657311  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-047] LOSS => Train : 0.0153533  Valid : 0.0522584  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-048] LOSS => Train : 0.0106273  Valid : 0.1124683  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-049] LOSS => Train : 0.0106561  Valid : 0.0643451  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-050] LOSS => Train : 0.0081984  Valid : 0.0347552  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-051] LOSS => Train : 0.0089705  Valid : 0.0606366  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-052] LOSS => Train : 0.0071070  Valid : 0.0450044  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-053] LOSS => Train : 0.0062318  Valid : 0.0550924  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-054] LOSS => Train : 0.0056020  Valid : 0.0639640  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-055] LOSS => Train : 0.0054211  Valid : 0.0626227  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-056] LOSS => Train : 0.0049155  Valid : 0.0608499  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-057] LOSS => Train : 0.0045700  Valid : 0.0613131  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-058] LOSS => Train : 0.0043814  Valid : 0.0556698  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-059] LOSS => Train : 0.0040959  Valid : 0.0466990  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-060] LOSS => Train : 0.0037853  Valid : 0.0452968  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-061] LOSS => Train : 0.0037680  Valid : 0.0532225  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-062] LOSS => Train : 0.0035232  Valid : 0.0575407  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-063] LOSS => Train : 0.0036866  Valid : 0.0742051  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-064] LOSS => Train : 0.0033006  Valid : 0.0489946  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-065] LOSS => Train : 0.0031299  Valid : 0.0556908  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-066] LOSS => Train : 0.0027788  Valid : 0.0533144  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-067] LOSS => Train : 0.0026740  Valid : 0.0463368  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-068] LOSS => Train : 0.0027495  Valid : 0.0554174  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-069] LOSS => Train : 0.0024630  Valid : 0.0479918  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-070] LOSS => Train : 0.0023874  Valid : 0.0465775  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-071] LOSS => Train : 0.0022675  Valid : 0.0513394  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-072] LOSS => Train : 0.0023325  Valid : 0.0588637  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-073] LOSS => Train : 0.0020815  Valid : 0.0487138  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-074] LOSS => Train : 0.0019022  Valid : 0.0506134  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-075] LOSS => Train : 0.0018526  Valid : 0.0441412  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-076] LOSS => Train : 0.0015642  Valid : 0.0549571  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-077] LOSS => Train : 0.0014907  Valid : 0.0631577  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-078] LOSS => Train : 0.0013738  Valid : 0.0647107  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-079] LOSS => Train : 0.0013202  Valid : 0.0611245  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-080] LOSS => Train : 0.0011542  Valid : 0.0553677  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-081] LOSS => Train : 0.0011019  Valid : 0.0528903  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-082] LOSS => Train : 0.0010417  Valid : 0.0465105  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-083] LOSS => Train : 0.0010160  Valid : 0.0438388  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-084] LOSS => Train : 0.0009692  Valid : 0.0550751  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-085] LOSS => Train : 0.0009126  Valid : 0.0499614  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-086] LOSS => Train : 0.0008479  Valid : 0.0511661  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-087] LOSS => Train : 0.0008273  Valid : 0.0527924  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-088] LOSS => Train : 0.0008119  Valid : 0.0525555  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-089] LOSS => Train : 0.0007707  Valid : 0.0544437  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-090] LOSS => Train : 0.0007433  Valid : 0.0514466  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-091] LOSS => Train : 0.0007170  Valid : 0.0489249  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-092] LOSS => Train : 0.0006950  Valid : 0.0466194  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-093] LOSS => Train : 0.0006774  Valid : 0.0494931  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-094] LOSS => Train : 0.0006647  Valid : 0.0457519  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-095] LOSS => Train : 0.0006521  Valid : 0.0522072  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-096] LOSS => Train : 0.0006174  Valid : 0.0476436  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-097] LOSS => Train : 0.0006007  Valid : 0.0489714  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-098] LOSS => Train : 0.0005882  Valid : 0.0500421  Acc => Train : 1.00000  Valid : 1.00000
# [EPOCH-099] LOSS => Train : 0.0005838  Valid : 0.0423103  Acc => Train : 1.00000  Valid : 1.00000

# %% [markdown]
# [6] 시각화 <hr>

# %%
uf.plot_history(HISTORY)
