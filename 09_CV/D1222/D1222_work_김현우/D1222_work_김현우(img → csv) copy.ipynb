# %% [markdown]
# #### [D1022_WORK_김현우]
# - 바나나랑 사과 사진 구분하기
# - 이진 분류

# %% [markdown]
# [1] 모듈 로딩 및 데이터 준비 <hr>

# %%
# -------------------------------------------------------------------------
# 1-1. 모듈 로딩 
# -------------------------------------------------------------------------
import cv2
import os

# 전처리
import pandas as pd
import numpy as np

# 시각화
import seaborn as sns
import koreanize_matplotlib
import matplotlib.pyplot as plt

# 머신러닝
from sklearn.ensemble import RandomForestClassifier

# -------------------------------------------------------------------------
# 1-2. 데이터 로딩
# -------------------------------------------------------------------------
FILE_NAME = './data/csv/fruits.csv'
fruitDF = pd.read_csv(FILE_NAME)

# %% [markdown]
# [2] 데이터 확인 및 전처리 <HR>
