# %% [markdown]
# ### 【기술통계 연습문제】
#
# - 각 문항에 대해 이론적 풀이와 함께 필요한 경우 파이썬 코드로도 계산
# - 코드 셀에 직접 계산 과정을 작성
# - 계산 시 소수 셋째 자리에서 반올림하여 소수 둘째 자리까지 표현

# %% [markdown]
# ##### 1. (기초) 평균 계산
# A반 시험 점수 :`[70, 75, 80, 90, 95]`
# 이 데이터의 **산술평균**을 구하시오.

# %%
# Q1 답안을 여기 작성하세요.
# 필요한 경우 파이썬 코드로 계산하세요.

# %% [markdown]
# ##### 2. (기초) 중앙값 계산
# 데이터: `[12, 4, 18, 5, 10]`
#
# 이 데이터의 **중앙값**을 구하시오.

# %%
# Q2 답안을 여기 작성하세요.
# 필요한 경우 파이썬 코드로 계산하세요.

# %% [markdown]
# ##### 3. (기초) 최빈값 계산
# 데이터: `[1, 1, 2, 2, 2, 3, 4]`
#
# 이 데이터의 **최빈값(mode)**을 구하시오.

# %%
# Q3 답안을 여기 작성하세요.
# 필요한 경우 파이썬 코드로 계산하세요.

# %% [markdown]
# ##### 4. (기초) 범위(Range) 계산
# 데이터: `[15, 22, 18, 30, 25]`
#
# 이 데이터의 **범위(최댓값 − 최솟값)**를 구하시오.

# %%
# Q4 답안을 여기 작성하세요.
# 필요한 경우 파이썬 코드로 계산하세요.

# %% [markdown]
# ##### 5. (중급) 분산(Variance) 계산
# 데이터: `[6, 8, 10, 14]`
#
# 1. **표본 분산(sample variance)**
# 2. **모분산(population variance)**
#
# 을 각각 계산하시오.

# %%
# Q5 답안을 여기 작성하세요.
# 필요한 경우 파이썬 코드로 계산하세요.

# %% [markdown]
# ##### 6. (중급) 표준편차(Standard Deviation) 계산
# 데이터: `[2, 3, 6, 8, 11]`
#
# 이 데이터의 **표본 표준편차**를 계산하시오.

# %%
# Q6 답안을 여기 작성하세요.
# 필요한 경우 파이썬 코드로 계산하세요.

# %% [markdown]
# ##### 7. (중급) 사분위수(Q1, Q2, Q3)를 구하시오.
# 데이터: `[3, 5, 7, 8, 9, 10, 12, 13]`
#
# Tukey 방식(하위/상위 절반에서 다시 중앙값을 계산하는 방식)을 사용하여
# - Q1 (제1사분위수)
# - Q2 (제2사분위수, 중앙값)
# - Q3 (제3사분위수)
# 를 구하시오.

# %%
# Q7 답안을 여기 작성하세요.
# 필요한 경우 파이썬 코드로 계산하세요.

# %% [markdown]
# ##### 8. (중급) IQR(사분위 범위)계산
# 데이터: `[10, 12, 13, 14, 16, 18, 20, 22]`
#
# Tukey 방식으로 Q1, Q3를 구한 뒤,
# IQR = Q3 − Q1 을 계산하시오.

# %%
# Q8 답안을 여기 작성하세요.
# 필요한 경우 파이썬 코드로 계산하세요.

# %% [markdown]
# ##### 9. (중급) 이상치(Outlier) 판단 – IQR 방식
# 데이터: `[5, 7, 8, 8, 9, 10, 12, 35]`
#
# 1. Tukey 방식으로 Q1, Q3, IQR을 구하시오.
# 2. 아래 공식을 사용하여 이상치 경계를 구하시오.
#    - 하한: Q1 − 1.5 × IQR
#    - 상한: Q3 + 1.5 × IQR
# 3. 이 데이터에서 **이상치(outlier)**가 존재하는지 판단하시오.

# %%
# Q9 답안을 여기 작성하세요.
# 필요한 경우 파이썬 코드로 계산하세요.

# %% [markdown]
# ##### 10. 왜도(Skewness)에 대한 개념 문제
# 다음 두 데이터 중 어느 쪽이 **왼쪽 쏠림, 오른쪽 꼬리 분포(양의 왜도, positive skew)**인지 고르시오.
#
# - 데이터 A: `[3, 4, 5, 6, 100]`
# - 데이터 B: `[10, 11, 12, 13, 14]`

# %%
# Q10 답안을 여기 작성하세요.
# 필요한 경우 파이썬 코드로 계산해 보세요.

# %% [markdown]
# ##### 11. 첨도(Kurtosis)에 대한 개념 문제
# 다음 두 데이터 중 어느 쪽이 **첨도(kurtosis)**가 더 클 가능성이 높은지 고르시오.
#
# - 데이터 A: `[10, 10, 11, 12, 50]`
# - 데이터 B: 정규분포에서 무작위로 추출된 데이터

# %%
# Q11 답안을 여기 작성하세요.
# 필요한 경우 파이썬 코드로 계산해보세요.

# %% [markdown]
# ##### 12. (응용) 로그 변환(Log Transform)과 정규성
# 다음과 같이 큰 값이 하나 포함된 데이터가 있다:
#
# `[3, 4, 5, 6, 200]`
#
# 이 데이터를 **정규분포에 더 가깝게** 만들기 위해 log 변환을 고려한다.
#
# 아래 보기 중 더 정규분포에 가까울 가능성이 높은 쪽을 고르시오.
# 1. 원본 데이터 그대로 사용
# 2. `log(x)` 변환 후 데이터 사용

# %%
# Q12 답안을 여기 작성하세요.
# 필요한 경우 파이썬 코드로 계산하세요.

# %% [markdown]
# ##### 13. (응용) Z-Score 계산
# 어떤 시험 점수의 분포에서 평균이 50점, 표준편차가 10점이다.
# 한 학생이 75점을 받았다.
#
# 이 학생의 **Z-score**를 계산하시오.
# (공식: Z = (x − μ) / σ)

# %%
# Q13 답안을 여기 작성하세요.
# 필요한 경우 파이썬 코드로 계산해 보세요.

# %% [markdown]
# ##### 14. (응용) 기술통계 기반 분포 형태 해석
# 어떤 데이터의 기술통계 결과가 다음과 같다.
#
# | 항목 | 값  |
# | --- | --- |
# | mean| 100 |
# | std |  50 |
# | 25% |  80 |
# | 50% |  95 |
# | 75% | 110 |
#
# 이 데이터를 보고 분포의 형태를 판단하시오.
#
# 1. 왼쪽 꼬리 치우친 분포 (음의 왜도)
# 2. 오른쪽 꼬리 치우친 분포 (양의 왜도)
# 3. 대칭 분포

# %%
# Q14 답안을 여기 작성하세요.
# 필요한 경우 파이썬 코드로 계산해 보세요.

# %% [markdown]
# ##### 15. (응용) Pandas describe() 결과 해석 (복수 선택 가능)
# 어떤 컬럼의 `describe()` 결과가 다음과 같다.
#
# ```
# count    1000
# mean     45.2
# std      30.1
# min       0.5
# 25%      17.4
# 50%      33.2
# 75%      60.7
# max     210.9
# ```
#
# 다음 해석 중 옳은 것을 모두 고르시오.
#
# A. 최소값과 최대값 차이가 크므로 분포가 퍼져 있다.
# B. 평균보다 중앙값이 더 작으므로 오른쪽 꼬리가 길다.
# C. 이상치가 존재할 가능성이 있다.
# D. IQR = 60.7 − 17.4 = 43.3 이다.

# %%
# Q15 답안을 여기 작성하세요.
# 필요한 경우 파이썬 코드로 계산해 보세요.
